# %%
# !pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("clmentbisaillon/fake-and-real-news-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\hmyrg\.cache\kagglehub\datasets\clmentbisaillon\fake-and-real-news-dataset\versions\1

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from textblob import TextBlob
from warnings import filterwarnings
filterwarnings('ignore')

# %%
fake_path = r"C:\Users\hmyrg\.cache\kagglehub\datasets\clmentbisaillon\fake-and-real-news-dataset\versions\1\Fake.csv"
true_path = r"C:\Users\hmyrg\.cache\kagglehub\datasets\clmentbisaillon\fake-and-real-news-dataset\versions\1\True.csv"

# Veri kümesini oku
df_fake = pd.read_csv(fake_path)
df_true = pd.read_csv(true_path)

# İlk 5 satırı göster
df_fake=pd.DataFrame(df_fake)
df_true=pd.DataFrame(df_true)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# !pip install textblob
# !pip install nltk

# %%
# !pip install xgboost
# !pip install keras
# !pip install tensorflow

# %%
from textblob import TextBlob
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, xgboost, numpy, textblob, string
from tensorflow.keras.preprocessing import text, sequence
from keras import layers, models, optimizers

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
print("Fake subject değerleri:", df_fake['subject'].unique())
print("True subject değerleri:", df_true['subject'].unique())
# Out:
# Fake subject değerleri: ['News' 'politics' 'Government News' 'left-news' 'US_News' 'Middle-east']
# True subject değerleri: ['politicsNews' 'worldnews']

# %%
df_fake['durum'] = 0  # Sahte haber
df_true['durum'] = 1  # Gerçek haber

# %%
df_fake["durum"].replace(0, value = "negatif", inplace = True)
df_true['durum'].replace(1, value = "pozitif", inplace = True)

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date    durum
# 0  December 31, 2017  negatif
# 1  December 31, 2017  negatif
# 2  December 30, 2017  negatif
# 3  December 29, 2017  negatif
# 4  December 25, 2017  negatif

# %%
data = pd.concat([df_fake, df_true], ignore_index=True)

# %%
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date    durum
# 0  December 31, 2017  negatif
# 1  December 31, 2017  negatif
# 2  December 30, 2017  negatif
# 3  December 29, 2017  negatif
# 4  December 25, 2017  negatif

# %%
data.groupby("durum").count()
# Out:
#          title   text  subject   date
# durum
# negatif  23481  23481    23481  23481
# pozitif  21417  21417    21417  21417

# %%
data.drop("date",axis=1,inplace=True)
data.drop("title",axis=1,inplace=True)

# %%
data.head()
# Out:
#                                                 text subject    durum
# 0  Donald Trump just couldn t wish all Americans ...    News  negatif
# 1  House Intelligence Committee Chairman Devin Nu...    News  negatif
# 2  On Friday, it was revealed that former Milwauk...    News  negatif
# 3  On Christmas day, Donald Trump announced that ...    News  negatif
# 4  Pope Francis used his annual Christmas Day mes...    News  negatif

# %% [markdown]
# ## metin ön işleme

# %%
#buyuk-kucuk donusumu
data['text'] = data['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
#noktalama işaretleri
data['text'] = data['text'].str.replace('[^\w\s]','')
#sayılar
data['text'] = data['text'].str.replace('\d','')
#stopwords
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('english')
data['text'] = data['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))
#seyreklerin silinmesi
sil = pd.Series(' '.join(data['text']).split()).value_counts()[-1000:]
data['text'] = data['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sil))
#lemmi
from textblob import Word
#nltk.download('wordnet')
data['text'] = data['text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
data.head()
# Out:
#                                                 text subject    durum
# 0  donald trump wish american happy new year leav...    News  negatif
# 1  house intelligence committee chairman devin nu...    News  negatif
# 2  friday, revealed former milwaukee sheriff davi...    News  negatif
# 3  christmas day, donald trump announced would ba...    News  negatif
# 4  pope francis used annual christmas day message...    News  negatif

# %% [markdown]
# ## Test-Train

# %%
train_x, test_x, train_y, test_y = model_selection.train_test_split(data["text"], data["durum"],test_size=0.33 ,random_state =42)

# %%
test_y[0:5]
# Out:
# 22216    negatif
# 27917    pozitif
# 25007    pozitif
# 1377     negatif
# 32476    pozitif
# Name: durum, dtype: object

# %%
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
test_y = encoder.fit_transform(test_y)

# %%
train_y[0:5]
# Out:
# array([1, 1, 0, 1, 0])

# %% [markdown]
# ## Değişken mühendisliği

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_x)
# Out:
# CountVectorizer()

# %%
x_train_count = vectorizer.transform(train_x)
x_test_count = vectorizer.transform(test_x)

# %% [markdown]
# ## TF-IDF

# %%
tf_idf_word_vectorizer = TfidfVectorizer()
tf_idf_word_vectorizer.fit(train_x)
# Out:
# TfidfVectorizer()

# %%
x_train_tf_idf_word = tf_idf_word_vectorizer.transform(train_x)
x_test_tf_idf_word = tf_idf_word_vectorizer.transform(test_x)

# %% [markdown]
# ## Makine öğrenmesi

# %% [markdown]
# ### Lojistik Regresyon

# %%
loj = linear_model.LogisticRegression()
loj_model = loj.fit(x_train_count, train_y)
accuracy = model_selection.cross_val_score(loj_model, 
                                           x_test_count, 
                                           test_y, 
                                           cv = 10).mean()

print("Count Vectors Doğruluk Oranı:", accuracy)
# Out:
# Count Vectors Doğruluk Oranı: 0.9948707469603736

# %%
loj = linear_model.LogisticRegression()
loj_model = loj.fit(x_train_tf_idf_word,train_y)
accuracy = model_selection.cross_val_score(loj_model, 
                                           x_test_tf_idf_word, 
                                           test_y, 
                                           cv = 10).mean()

print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.9835327098715989

# %% [markdown]
# ### Naive Bayes

# %%
nb = naive_bayes.MultinomialNB()
nb_model = nb.fit(x_train_count,train_y)
accuracy = model_selection.cross_val_score(nb_model, 
                                           x_test_count, 
                                           test_y, 
                                           cv = 10).mean()

print("Count Vectors Doğruluk Oranı:", accuracy)
# Out:
# Count Vectors Doğruluk Oranı: 0.952217471690445

# %%
nb = naive_bayes.MultinomialNB()
nb_model = nb.fit(x_train_tf_idf_word,train_y)
accuracy = model_selection.cross_val_score(nb_model, 
                                           x_test_tf_idf_word, 
                                           test_y, 
                                           cv = 10).mean()

print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.9385177156259996

# %% [markdown]
# ## Random forest

# %%
rf = ensemble.RandomForestClassifier()
rf_model = rf.fit(x_train_count,train_y)
accuracy = model_selection.cross_val_score(rf_model, 
                                           x_test_count, 
                                           test_y, 
                                           cv = 10).mean()

print("Count Vectors Doğruluk Oranı:", accuracy)
# Out:
# Count Vectors Doğruluk Oranı: 0.9876497260395052

# %%
rf = ensemble.RandomForestClassifier()
rf_model = rf.fit(x_train_tf_idf_word,train_y)
accuracy = model_selection.cross_val_score(rf_model, 
                                           x_test_tf_idf_word, 
                                           test_y, 
                                           cv = 10).mean()

print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.9877846332446708

# %% [markdown]
# ## XGBoost

# %%
# Eğitim ve test skorlarını ayrı ayrı hesapla
loj = linear_model.LogisticRegression()
loj.fit(x_train_count, train_y)
print("Eğitim doğruluğu:", loj.score(x_train_count, train_y))
print("Test doğruluğu:", loj.score(x_test_count, test_y))
# Out:
# Eğitim doğruluğu: 0.999966756424321
# Test doğruluğu: 0.9961530674225552

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = loj.predict(x_test_count)
print(confusion_matrix(test_y, y_pred))
print(classification_report(test_y, y_pred))
# Out:
# [[7747   31]
#  [  26 7013]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7778
#            1       1.00      1.00      1.00      7039
#
#     accuracy                           1.00     14817
#    macro avg       1.00      1.00      1.00     14817
# weighted avg       1.00      1.00      1.00     14817

# %%
loj_model
# Out:
# LogisticRegression()

# %%
# Örnek: eğitimi yaptığın CountVectorizer ile metni vektöre çevir
new_text = ["yes i like this film"]
new_text_vectorized = vectorizer.transform(new_text)  # Burada vectorizer, x_train_count'ı üreten nesne

# Tahmin
prediction = loj_model.predict(new_text_vectorized)
print("Tahmin:", prediction)
# Out:
# Tahmin: [0]

# %%
# Örnek: eğitimi yaptığın CountVectorizer ile metni vektöre çevir
new_text = ["Türkiye İstatistik Kurumu (TÜİK), milyonlarca memur ve emekli maaş zammını doğrudan etkileyen Mayıs ayı enflasyon verilerini açıkladı.
TÜİK’in verilerine göre, Mayıs ayında aylık enflasyon yüzde 1.53, yıllık yüzde 35.41 olarak gerçekleşti. Böylece, memur ve emekli maaşlarına yapılacak zam oranlarını belirleyen beş aylık enflasyon verileri de netleşmiş oldu."]
new_text_vectorized = vectorizer.transform(new_text)  # Burada vectorizer, x_train_count'ı üreten nesne

# Tahmin
prediction = loj_model.predict(new_text_vectorized)
print("Tahmin:", prediction)
# Out:
#   Cell In[126], line 2
#     new_text = ["Türkiye İstatistik Kurumu (TÜİK), milyonlarca memur ve emekli maaş zammını doğrudan etkileyen Mayıs ayı enflasyon verilerini açıkladı.
#                 ^
# SyntaxError: unterminated string literal (detected at line 2)
